# %%
import random
#select = int(input('please select 1 or 2 players: '))
#input_position = int(input('please enter X or O position: '))

b_p = [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
turn = True
start_it = True
not_full_board = 1
my_turn = True




def board():     
    print('',b_p[1], '|', b_p[2], '|', b_p[3], '\n---+---+---\n', b_p[4], '|', b_p[5], '|', b_p[6], '\n---+---+---\n', b_p[7], '|', b_p[8], '|', b_p[9], '\n')
    
#board()


def postion(pos, letter):
    if b_p[pos] == ' ':
        b_p[pos] = letter
        return True
    else:
        print('this postion not empty')
        return False

        #board() 
#postion(input_position, 'X')

def com_postion(pos, letter):
    if b_p[pos] == ' ':
        b_p[pos] = letter
        return True
    else:
        print('this postion not empty')
        return False


def full_board():
    if b_p.count(' ') == 1:
        print('game tie')
        return True
    else:
        return False





def player1():
        if input_position >= 1 and input_position <= 9:
            return postion(input_position, 'X')
#player1(postion(input_position, 'X'))


def player2():      
        if input_position >= 1 and input_position <= 9:
            return postion(input_position, 'O')
#player1(postion(input_position, 'O'))

def com():
    boardcopy = b_p
    letter = []
    for pos in range(10): # starting from 1 not from 0 
        #print(pos)
        if pos != 0: # so you can 
            if boardcopy[1] == 'O' and boardcopy[2] == 'O':
                if boardcopy[3] == ' ':
                    letter.append('O') # use insert method 
                    boardcopy[3] = letter[0]
                    return letter
                else:
                    if boardcopy[pos] == ' ':
                        letter.append('O')
                        boardcopy[pos] = letter[0]
                        return letter
                
            if boardcopy[1] == 'O' and boardcopy[3] == 'O':
                if boardcopy[2] == ' ':
                    letter.append('O')
                    boardcopy[2] = letter[0]
                    return letter
                else:
                    if boardcopy[pos] == ' ':
                        letter.append('O')
                        boardcopy[pos] = letter[0]
                        return letter
                
            if boardcopy[2] == 'O' and boardcopy[3] == 'O':
                if boardcopy[1] == ' ':
                    letter.append('O')
                    boardcopy[1] = letter[0]
                    return letter
                else:
                    if boardcopy[pos] == ' ':
                        letter.append('O')
                        boardcopy[pos] = letter[0]
                        return letter

            if boardcopy[4] == 'O' and boardcopy[5] == 'O':
                if boardcopy[6] == ' ':
                    letter.append('O')
                    boardcopy[6] = letter[0]
                    return letter
                else:
                    if boardcopy[pos] == ' ':
                        letter.append('O')
                        boardcopy[pos] = letter[0]
                        return letter

            if boardcopy[4] == 'O' and boardcopy[6] == 'O':
                if boardcopy[5] == ' ':
                    letter.append('O')
                    boardcopy[5] = letter[0]
                    return letter
                else:
                    if boardcopy[pos] == ' ':
                        letter.append('O')
                        boardcopy[pos] = letter[0]
                        return letter

            if boardcopy[5] == 'O' and boardcopy[6] == 'O':
                if boardcopy[4] == ' ':
                    letter.append('O')
                    boardcopy[4] = letter[0]
                    return letter
                else:
                    if boardcopy[pos] == ' ':
                        letter.append('O')
                        boardcopy[pos] = letter[0]
                        return letter

            if boardcopy[7] == 'O' and boardcopy[8] == 'O':
                if boardcopy[9] == ' ':
                    letter.append('O')
                    boardcopy[9] = letter[0]
                    return letter
                else:
                    if boardcopy[pos] == ' ':
                        letter.append('O')
                        boardcopy[pos] = letter[0]
                        return letter
            
            if boardcopy[7] == 'O' and boardcopy[9] == 'O':
                if boardcopy[8] == ' ':
                    letter.append('O')
                    boardcopy[8] = letter[0]
                    return letter
                else:
                    if boardcopy[pos] == ' ':
                        letter.append('O')
                        boardcopy[pos] = letter[0]
                        return letter

            if boardcopy[8] == 'O' and boardcopy[9] == 'O':
                if boardcopy[7] == ' ':
                    letter.append('O')
                    boardcopy[7] = letter[0]
                    return letter
                else:
                    if boardcopy[pos] == ' ':
                        letter.append('O')
                        boardcopy[pos] = letter[0]
                        return letter

            if boardcopy[1] == 'O' and boardcopy[4] == 'O':
                if boardcopy[7] == ' ':
                    letter.append('O')
                    boardcopy[7] = letter[0]
                    return letter
                else:
                    if boardcopy[pos] == ' ':
                        letter.append('O')
                        boardcopy[pos] = letter[0]
                        return letter

            if boardcopy[1] == 'O' and boardcopy[7] == 'O':
                if boardcopy[4] == ' ':
                    letter.append('O')
                    boardcopy[4] = letter[0]
                    return letter
                else:
                    if boardcopy[pos] == ' ':
                        letter.append('O')
                        boardcopy[pos] = letter[0]
                        return letter
 
            if boardcopy[4] == 'O' and boardcopy[7] == 'O':
                if boardcopy[1] == ' ':
                    letter.append('O')
                    boardcopy[1] = letter[0]
                    return letter
                else:
                    if boardcopy[pos] == ' ':
                        letter.append('O')
                        boardcopy[pos] = letter[0]
                        return letter

            if boardcopy[2] == 'O' and boardcopy[5] == 'O':
                if boardcopy[8] == ' ':
                    letter.append('O')
                    boardcopy[8] = letter[0]
                    return letter
                else:
                    if boardcopy[pos] == ' ':
                        letter.append('O')
                        boardcopy[pos] = letter[0]
                        return letter

            if boardcopy[2] == 'O' and boardcopy[8] == 'O':
                if boardcopy[5] == ' ':
                    letter.append('O')
                    boardcopy[5] = letter[0]
                    return letter
                else:
                    if boardcopy[pos] == ' ':
                        letter.append('O')
                        boardcopy[pos] = letter[0]
                        return letter

            if boardcopy[5] == 'O' and boardcopy[8] == 'O':
                if boardcopy[2] == ' ':
                    letter.append('O')
                    boardcopy[2] = letter[0]
                    return letter
                else:
                    if boardcopy[pos] == ' ':
                        letter.append('O')
                        boardcopy[pos] = letter[0]
                        return letter

            if boardcopy[3] == 'O' and boardcopy[6] == 'O':
                if boardcopy[9] == ' ':
                    letter.append('O')
                    boardcopy[9] = letter[0]
                    return letter
                else:
                    if boardcopy[pos] == ' ':
                        letter.append('O')
                        boardcopy[pos] = letter[0]
                        return letter

            if boardcopy[3] == 'O' and boardcopy[9] == 'O':
                if boardcopy[6] == ' ':
                    letter.append('O')
                    boardcopy[6] = letter[0]
                    return letter
                else:
                    if boardcopy[pos] == ' ':
                        letter.append('O')
                        boardcopy[pos] = letter[0]
                        return letter

            if boardcopy[6] == 'O' and boardcopy[9] == 'O':
                if boardcopy[3] == ' ':
                    letter.append('O')
                    boardcopy[3] = letter[0]
                    return letter
                else:
                    if boardcopy[pos] == ' ':
                        letter.append('O')
                        boardcopy[pos] = letter[0]
                        return letter
            
            if boardcopy[1] == 'O' and boardcopy[5] == 'O':
                if boardcopy[9] == ' ':
                    letter.append('O')
                    boardcopy[9] = letter[0]
                    return letter
                else:
                    if boardcopy[pos] == ' ':
                        letter.append('O')
                        boardcopy[pos] = letter[0]
                        return letter
            
            if boardcopy[1] == 'O' and boardcopy[9] == 'O':
                if boardcopy[5] == ' ':
                    letter.append('O')
                    boardcopy[5] = letter[0]
                    return letter
                else:
                    if boardcopy[pos] == ' ':
                        letter.append('O')
                        boardcopy[pos] = letter[0]
                        return letter

            if boardcopy[5] == 'O' and boardcopy[9] == 'O':
                if boardcopy[1] == ' ':
                    letter.append('O')
                    boardcopy[1] = letter[0]
                    return letter
                else:
                    if boardcopy[pos] == ' ':
                        letter.append('O')
                        boardcopy[pos] = letter[0]
                        return letter

            if boardcopy[3] == 'O' and boardcopy[5] == 'O':
                if boardcopy[7] == ' ':
                    letter.append('O')
                    boardcopy[7] = letter[0]
                    return letter
                else:
                    if boardcopy[pos] == ' ':
                        letter.append('O')
                        boardcopy[pos] = letter[0]
                        return letter

            if boardcopy[3] == 'O' and boardcopy[7] == 'O':
                if boardcopy[5] == ' ':
                    letter.append('O')
                    boardcopy[5] = letter[0]
                    return letter
                else:
                    if boardcopy[pos] == ' ':
                        letter.append('O')
                        boardcopy[pos] = letter[0]
                        return letter

            if boardcopy[5] == 'O' and boardcopy[7] == 'O':
                if boardcopy[3] == ' ':
                    letter.append('O')
                    boardcopy[3] = letter[0]
                    return letter
                else:
                    if boardcopy[pos] == ' ':
                        letter.append('O')
                        boardcopy[pos] = letter[0]
                        return letter

     #----------------------------------------------#
            
            if boardcopy[1] == 'X' and boardcopy[2] == 'X':
                if boardcopy[3] == ' ':
                    letter.append('O')
                    boardcopy[3] = letter[0]
                    return letter
                
            if boardcopy[1] == 'X' and boardcopy[3] == 'X':
                if boardcopy[2] == ' ':
                    letter.append('O')
                    boardcopy[2] = letter[0]
                    return letter
                
            if boardcopy[2] == 'X' and boardcopy[3] == 'X':
                if boardcopy[1] == ' ':
                    letter.append('O')
                    boardcopy[1] = letter[0]
                    return letter

            if boardcopy[4] == 'X' and boardcopy[5] == 'X':
                if boardcopy[6] == ' ':
                    letter.append('O')
                    boardcopy[6] = letter[0]
                    return letter

            if boardcopy[4] == 'X' and boardcopy[6] == 'X':
                if boardcopy[5] == ' ':
                    letter.append('O')
                    boardcopy[5] = letter[0]
                    return letter

            if boardcopy[5] == 'X' and boardcopy[6] == 'X':
                if boardcopy[4] == ' ':
                    letter.append('O')
                    boardcopy[4] = letter[0]
                    return letter

            if boardcopy[7] == 'X' and boardcopy[8] == 'X':
                if boardcopy[9] == ' ':
                    letter.append('O')
                    boardcopy[9] = letter[0]
                    return letter
            
            if boardcopy[7] == 'X' and boardcopy[9] == 'X':
                if boardcopy[8] == ' ':
                    letter.append('O')
                    boardcopy[8] = letter[0]
                    return letter

            if boardcopy[8] == 'X' and boardcopy[9] == 'X':
                if boardcopy[7] == ' ':
                    letter.append('O')
                    boardcopy[7] = letter[0]
                    return letter

            if boardcopy[1] == 'X' and boardcopy[4] == 'X':
                if boardcopy[7] == ' ':
                    letter.append('O')
                    boardcopy[7] = letter[0]
                    return letter

            if boardcopy[1] == 'X' and boardcopy[7] == 'X':
                if boardcopy[4] == ' ':
                    letter.append('O')
                    boardcopy[4] = letter[0]
                    return letter
 
            if boardcopy[4] == 'X' and boardcopy[7] == 'X':
                if boardcopy[1] == ' ':
                    letter.append('O')
                    boardcopy[1] = letter[0]
                    return letter

            if boardcopy[2] == 'X' and boardcopy[5] == 'X':
                if boardcopy[8] == ' ':
                    letter.append('O')
                    boardcopy[8] = letter[0]
                    return letter

            if boardcopy[2] == 'X' and boardcopy[8] == 'X':
                if boardcopy[5] == ' ':
                    letter.append('O')
                    boardcopy[5] = letter[0]
                    return letter

            if boardcopy[5] == 'X' and boardcopy[8] == 'X':
                if boardcopy[2] == ' ':
                    letter.append('O')
                    boardcopy[2] = letter[0]
                    return letter

            if boardcopy[3] == 'X' and boardcopy[6] == 'X':
                if boardcopy[9] == ' ':
                    letter.append('O')
                    boardcopy[9] = letter[0]
                    return letter

            if boardcopy[3] == 'X' and boardcopy[9] == 'X':
                if boardcopy[6] == ' ':
                    letter.append('O')
                    boardcopy[6] = letter[0]
                    return letter

            if boardcopy[6] == 'X' and boardcopy[9] == 'X':
                if boardcopy[3] == ' ':
                    letter.append('O')
                    boardcopy[3] = letter[0]
                    return letter
            
            if boardcopy[1] == 'X' and boardcopy[5] == 'X':
                if boardcopy[9] == ' ':
                    letter.append('O')
                    boardcopy[9] = letter[0]
                    return letter
            
            if boardcopy[1] == 'X' and boardcopy[9] == 'X':
                if boardcopy[5] == ' ':
                    letter.append('O')
                    boardcopy[5] = letter[0]
                    return letter

            if boardcopy[5] == 'X' and boardcopy[9] == 'X':
                if boardcopy[1] == ' ':
                    letter.append('O')
                    boardcopy[1] = letter[0]
                    return letter

            if boardcopy[3] == 'X' and boardcopy[5] == 'X':
                if boardcopy[7] == ' ':
                    letter.append('O')
                    boardcopy[7] = letter[0]
                    return letter

            if boardcopy[3] == 'X' and boardcopy[7] == 'X':
                if boardcopy[5] == ' ':
                    letter.append('O')
                    boardcopy[5] = letter[0]
                    return letter

            if boardcopy[5] == 'X' and boardcopy[7] == 'X':
                if boardcopy[3] == ' ':
                    letter.append('O')
                    boardcopy[3] = letter[0]
                    return letter
        
        #----------------------------------------------#
            
            elif boardcopy[5] == ' ': 
                letter.append('O')
                boardcopy[5] = letter[0]
                return letter
                
            else:
                if boardcopy[pos] == ' ':
                    letter.append('O')
                    boardcopy[pos] = letter[0]
                    return letter
                    


def choice():
    while True:
        select = int(input('please select 1 or 2 players: '))
        if select == 2:
            return 2
        elif select == 1:
            return 1
        else:
            print('please insert 1 or 2 players only')
#choice()






def winner(board, letter, print_X = False, print_O = False):
    #X and O
    if (  (board[1] == letter and board[2] == letter and board[3] == letter) or (board[4] == letter and board[5] == letter and board[6] == letter) 
       or (board[7] == letter and board[8] == letter and board[9] == letter) or (board[1] == letter and board[4] == letter and board[7] == letter) 
       or (board[2] == letter and board[5] == letter and board[8] == letter) or (board[3] == letter and board[6] == letter and board[9] == letter) 
       or (board[1] == letter and board[5] == letter and board[9] == letter) or (board[3] == letter and board[5] == letter and board[7] == letter)):
        if print_X:
            print(letter, ' is winner')
        elif print_O:
            print(letter, ' is winner')
        return True
    else:
        return False
    

#winner()
def check():
    while True:
        re_game = input('if you want play again please insert y or yes \n if you want stop playing  please insert n or no: ')
        if re_game.lower() == 'y' or re_game.lower() == 'yes':
            return True

        elif re_game.lower() == 'n' or re_game.lower() == 'no':
            print('See you later')
            #print('break 1')
            return False






#postion(pos, letter) = True
#b_p 
choose = choice() 
if choose == 2:

    while True:
        if start_it:
            start = input('please select s or S to start the game: ')
            if start == 's' or start == 'S':

                print('Welcome to tic tac toe game please enjoy the game')
                start_it = False
            else:
                print('please select s or S to start the game')
                continue
        board()
        #input_position()
        #print('1', b_p[input_position])
        if my_turn == True:
            turn = random.choice([True, False])
            my_turn = False
        else:
            pass

        if turn == True:
            input_position = int(input('please enter X position: '))
            p1 = player1()
            if p1:
                turn = False

        elif turn == False: 
            input_position = int(input('please enter O position: '))  
            p2 = player2()
            if p2:
                turn = True

            
        if winner(b_p, 'X', print_X = True) or winner(b_p, 'O', print_O = True) or full_board():
            # print('ana fi winner')
            board()
            if check() == True:
                if winner(b_p, 'X'):
                    b_p = [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
                    start_it = True
                    turn = True
                    continue

                elif winner(b_p, 'O'):
                    b_p = [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
                    start_it = True
                    turn = False
                    continue
                else:
                    b_p = [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
                    start_it = True
                    my_turn = True
                continue
            else:
                break

                   
if choose == 1:

    while True:
        if start_it:
            start = input('please select s or S to start the game: ')
            if start == 's' or start == 'S':

                print('Welcome to tic tac toe game please enjoy the game')
                start_it = False
            else:
                print('please select s or S to start the game')
                continue
        board()
        #input_position()
        #print('1', b_p[input_position])
        if my_turn == True:
            turn = random.choice([True, False])
            my_turn = False
        else:
            pass

        if turn == True:
            input_position = int(input('please enter X position: '))
            p1 = player1()
            if p1:
                turn = False

        elif turn == False: 
            #input_position = int(input('please enter O position: '))  
            c = com()
            print('com turn')
            if c:
                turn = True

            
        if winner(b_p, 'X', print_X = True) or winner(b_p, 'O', print_O = True) or full_board():
            # print('ana fi winner')
            board()
            if check() == True:
                if winner(b_p, 'X'):
                    b_p = [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
                    start_it = True
                    turn = True
                    continue

                elif winner(b_p, 'O'):
                    b_p = [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
                    start_it = True
                    turn = False
                    continue
                
                else:
                    b_p = [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
                    start_it = True
                    my_turn = True
                continue

            else:
                break
# Out:
# please select 1 or 2 players:  1
# please select s or S to start the game:  s
# Welcome to tic tac toe game please enjoy the game
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
# please enter X position:  1
#  X |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# com turn
#  X |   |
# ---+---+---
#    | O |
# ---+---+---
#    |   |
# please enter X position:  3
#  X |   | X
# ---+---+---
#    | O |
# ---+---+---
#    |   |
#
# com turn
#  X | O | X
# ---+---+---
#    | O |
# ---+---+---
#    |   |
# please enter X position:  8
#  X | O | X
# ---+---+---
#    | O |
# ---+---+---
#    | X |
#
# com turn
#  X | O | X
# ---+---+---
#  O | O |
# ---+---+---
#    | X |
# please enter X position:  6
#  X | O | X
# ---+---+---
#  O | O | X
# ---+---+---
#    | X |
#
# com turn
#  X | O | X
# ---+---+---
#  O | O | X
# ---+---+---
#    | X | O
# please enter X position:  7
# game tie
#  X | O | X
# ---+---+---
#  O | O | X
# ---+---+---
#  X | X | O
# ...

# %%
import random
#select = int(input('please select 1 or 2 players: '))
#input_position = int(input('please enter X or O position: '))

b_p = [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
turn = True
start_it = True
not_full_board = 1
my_turn = True




def board():     
    print('',b_p[1], '|', b_p[2], '|', b_p[3], '\n---+---+---\n', b_p[4], '|', b_p[5], '|', b_p[6], '\n---+---+---\n', b_p[7], '|', b_p[8], '|', b_p[9], '\n')
    
#board()


def postion(pos, letter):
    if b_p[pos] == ' ':
        b_p[pos] = letter
        return True
    else:
        print('this postion not empty')
        return False

        #board() 
#postion(input_position, 'X')

def com_postion(pos, letter):
    if b_p[pos] == ' ':
        b_p[pos] = letter
        return True
    else:
        print('this postion not empty')
        return False


def full_board():
    if b_p.count(' ') == 1:
        print('game tie')
        return True
    else:
        return False





def player1():
        if input_position >= 1 and input_position <= 9:
            return postion(input_position, 'X')
#player1(postion(input_position, 'X'))


def player2():      
        if input_position >= 1 and input_position <= 9:
            return postion(input_position, 'O')
#player1(postion(input_position, 'O'))

def com():
    a = [1,3,7,9]
    letter = []
    possibleMoves = [i for i, v in enumerate(b_p) if v == ' ' and i != 0]

    for let in ['X', 'O']:
        for x in possibleMoves:
            boardcopy = b_p[:]
            boardcopy[x] = let
            if winner(boardcopy, let) or winner(boardcopy, let):
                return postion(x, 'O')
            
    if boardcopy[5] == ' ': 
        letter.append('O')
        boardcopy[5] = letter[0]
        return postion(5, 'O')

    elif a == [1,3,7,9]:
        pos = random.choice(a)
        if boardcopy[pos] == ' ':
            letter.append('O')
            boardcopy[pos] = letter[0]
            return postion(pos, 'O')

    else:
        for pos in range(10):
            if pos != 0:
                if boardcopy[pos] == ' ':
                    letter.append('O')
                    boardcopy[pos] = letter[0]
                    return postion(pos, 'O')
                    


def choice():
    while True:
        select = int(input('please select 1 or 2 players: '))
        if select == 2:
            return 2
        elif select == 1:
            return 1
        else:
            print('please insert 1 or 2 players only')
#choice()






def winner(board, letter, print_X = False, print_O = False):
    #X and O
    if (  (board[1] == letter and board[2] == letter and board[3] == letter) or (board[4] == letter and board[5] == letter and board[6] == letter) 
       or (board[7] == letter and board[8] == letter and board[9] == letter) or (board[1] == letter and board[4] == letter and board[7] == letter) 
       or (board[2] == letter and board[5] == letter and board[8] == letter) or (board[3] == letter and board[6] == letter and board[9] == letter) 
       or (board[1] == letter and board[5] == letter and board[9] == letter) or (board[3] == letter and board[5] == letter and board[7] == letter)):
        if print_X:
            print(letter, ' is winner')
        elif print_O:
            print(letter, ' is winner')
        return True
    else:
        return False
    

#winner()
def check():
    while True:
        re_game = input('if you want play again please insert y or yes \n if you want stop playing  please insert n or no: ')
        if re_game.lower() == 'y' or re_game.lower() == 'yes':
            return True

        elif re_game.lower() == 'n' or re_game.lower() == 'no':
            print('See you later')
            #print('break 1')
            return False






#postion(pos, letter) = True
#b_p 
choose = choice() 
if choose == 2:

    while True:

        if start_it:
            start = input('please select s or S to start the game: ')
            if start == 's' or start == 'S':

                print('Welcome to tic tac toe game please enjoy the game')
                start_it = False
            else:
                print('please select s or S to start the game')
                continue
        board()
        #input_position()
        #print('1', b_p[input_position])
        if my_turn == True:
            turn = random.choice([True, False])
            my_turn = False
 

        if turn == True:
            input_position = int(input('please enter X position: '))
            p1 = player1()
            if p1:
                turn = False

        elif turn == False: 
            input_position = int(input('please enter O position: '))  
            p2 = player2()
            if p2:
                turn = True

            
        if winner(b_p, 'X', print_X = True) or winner(b_p, 'O', print_O = True) or full_board():
            # print('ana fi winner')
            board()
            if check() == True:
                if winner(b_p, 'X'):
                    b_p = [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
                    start_it = True
                    turn = True
                    continue

                elif winner(b_p, 'O'):
                    b_p = [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
                    start_it = True
                    turn = False
                    continue
                else:
                    b_p = [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
                    start_it = True
                    my_turn = True
                continue
            else:
                break
        else:
            continue

                   
if choose == 1:

    while True:
        if start_it:
            start = input('please select s or S to start the game: ')
            if start == 's' or start == 'S':

                print('Welcome to tic tac toe game please enjoy the game')
                start_it = False
            else:
                print('please select s or S to start the game')
                continue
        board()
        #input_position()
        #print('1', b_p[input_position])
        if my_turn == True:
            turn = random.choice([True, False])
            my_turn = False

        if turn == True:
            input_position = int(input('please enter X position: '))
            p1 = player1()
            if p1:
                turn = False

        elif turn == False: 
            #input_position = int(input('please enter O position: '))  
            c = com()
            print('com turn')
            if c:
                turn = True

            
        if winner(b_p, 'X', print_X = True) or winner(b_p, 'O', print_O = True) or full_board():
            # print('ana fi winner')
            board()
            if check() == True:
                if winner(b_p, 'X'):
                    b_p = [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
                    start_it = True
                    turn = True
                    continue

                elif winner(b_p, 'O'):
                    b_p = [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
                    start_it = True
                    turn = False
                    continue
                
                else:
                    b_p = [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
                    start_it = True
                    my_turn = True
                continue

            else:
                break
        else:
            continue
# Out:
# please select 1 or 2 players:  2
# please select s or S to start the game:  s
# Welcome to tic tac toe game please enjoy the game
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
# please enter O position:  1
#  O |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
# please enter X position:  2
#  O | X |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
# please enter O position:  3
#  O | X | O
# ---+---+---
#    |   |
# ---+---+---
#    |   |
# please enter X position:  4
#  O | X | O
# ---+---+---
#  X |   |
# ---+---+---
#    |   |
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9592\2061770536.py in <module>
#     175
#     176         elif turn == False:
# --> 177             input_position = int(input('please enter O position: '))
#     178             p2 = player2()
#     179             if p2:
#
# ...
